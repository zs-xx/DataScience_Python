# %%
import numpy as np
import pandas as pd 
import seaborn as sns
sns.set()
df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2', index_col=0)

# %%
df1['A'].hist(bins=20)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: xlabel='a'>

# %%
df2.plot.bar()
# Out:
# <Axes: xlabel='a'>

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='a'>

# %%
df1.plot.line(y='A', figsize=(12, 3))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='B', y='A', s=df1['C']*50, c='C', cmap='berlin')
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='B', ylabel='A'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
